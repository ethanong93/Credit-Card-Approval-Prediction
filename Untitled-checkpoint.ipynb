# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import statistics

# %%
data_sp=[100,60,95,75,100,60,95,75,109,80,109,75]
data_ipad=[50,55,51,40,30,39,45,56,39,48,44]
data_ps5=[180,199,93,80,70,65,85,90,80,75,65,80]

# %%
statistics.mean(data_ipad)
# Out:
# 45.18181818181818

# %%
statistics.median(data_ipad)
# Out:
# 45

# %%
updated_data_ipad=[50,55,51,40,45,30,39,45,56,39,48,44]

# %%
statistics.median(updated_data_ipad)
# Out:
# 45.0

# %%
statistics.mean(updated_data_ipad)
# Out:
# 45.166666666666664

# %%
sum(data_sp)
# Out:
# 1033

# %%
sum(updated_data_ipad)
# Out:
# 542

# %%
sum(data_ps5)
# Out:
# 1162

# %%
min(data_sp)
# Out:
# 60

# %%
max(updated_data_ipad)
# Out:
# 56

# %%
max(data_ps5)
# Out:
# 199

# %%
data = [data_sp, updated_data_ipad, data_ps5]
fig = plt.figure(figsize =(10, 7))
 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(data,vert=False,meanline =True)
ax.set_yticklabels(['data_1', 'data_2',
                    'data_3'])
plt.title('Sales of Electronic Products for the year 2021')
# show plot
plt.show()

# %%
from pylab import *
fig = figure(figsize=(10,6))  # define the figure window
ax  = fig.add_subplot(111)   # define the axis
labels = ('random set 1', 'random set 2','3')
bp_dict = ax.boxplot(data, vert=False)
ax.set_yticklabels(['Smart Phone', 'Ipad',
                    'Playstation 5'])

for line in bp_dict['medians']:
    # get position data for median line
    x, y = line.get_xydata()[1] # top of median line
    # overlay median value
    text(x, y, '%.1f' % x,
         horizontalalignment='center') # draw above, centered

for line in bp_dict['boxes']:
    x, y = line.get_xydata()[0] # bottom of left line
    text(x,y, '%.1f' % x,
         horizontalalignment='center', # centered
         verticalalignment='top')      # below
    x, y = line.get_xydata()[3] # bottom of right line
    text(x,y, '%.1f' % x,
         horizontalalignment='center', # centered
             verticalalignment='top')      # below
ylabel("Products")
xlabel("Item Sold")
title('Sales of Electronic Products for the year 2021')

show()

# %%
fig = figure(figsize=(4,4))  # define the figure window
ax  = fig.add_subplot(111)   # define the axis

ax.boxplot(data, vert=False)       # make your boxplot

# add axis texts
ax.set_xlabel('X-label', fontsize=8)
ax.set_ylabel('Y-label', fontsize=8)
ax.set_title('I AM BOXPLOT', fontsize=10)
# format axes
ax.set_xlim([0,100])
ax.set_xticks( np.arange(0,101,10), minor=False)
ax.set_xticks( np.arange(0,100,5),  minor=True)

# if you wish to explicitly set tick labels
ax.set_yticklabels( np.arange(0,101,10), fontsize=8)

# if you wish to explicitly set actual tick parameters
ax.tick_params(axis='both',which='major',direction='in',length=4,width=2,labelsize=8)
ax.tick_params(axis='both',which='minor',direction='in',length=2,width=1.5)  
show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 16
#      13 ax.set_xticks( np.arange(0,100,5),  minor=True)
#      15 # if you wish to explicitly set tick labels
# ---> 16 ax.set_yticklabels( np.arange(0,101,10), fontsize=8)
#      18 # if you wish to explicitly set actual tick parameters
#      19 ax.tick_params(axis='both',which='major',direction='in',length=4,width=2,labelsize=8)
#
# File ~\anaconda3\envs\py310\lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~\anaconda3\envs\py310\lib\site-packages\matplotlib\axis.py:1968, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1966 if fontdict is not None:
#    1967     kwargs.update(fontdict)
# ...
